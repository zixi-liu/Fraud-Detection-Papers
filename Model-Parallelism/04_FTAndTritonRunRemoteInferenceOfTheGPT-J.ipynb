# %% [markdown]
# <img src="./images/DLI_Header.png" style="width: 400px;">

# %% [markdown]
# # 4. GPT-J deployment with NVIDIA FasterTransformer and Triton Inference server
#
# In the previous section, we have seen how to take an unoptimized model and significantly accelerate it using FasterTransformer. This is significant, as it allows us to dramatically reduce the size of the capital investment needed to deploy an application as well as the ongoing operational costs. FasterTransformer can frequently be the difference between a non-feasible idea and a product that generates revenue. At the end of the previous notebook, we only had a binary with no real means of serving it to large groups of users. We did not have a way to deploy this binary to production, not to mention, to manage the efficiency of its execution (for example, batching user requests together to increase GPU utilization or overlapping execution of models to reduce request latency). We will address the above and have an application that is close to being ready for production.
#
# In this notebook we will:
# * Discuss key features of NVIDIA Triton inference server and how it can be integrated with the FasterTransformer Execution Backend.
# * Learn how to prepare the GPT-J for deployment using Triton.
# * Run Triton inference server with GPT-J using a two-way Tensor Parallel deployment.
# * We will write a client application using our model hosted on Triton using Python client API `tritonclient`
#
#
# **[4.1 NVIDIA Triton Inference Server](#4.1)<br>**
# **[4.2 Overview of the end-to-end inference pipeline](#4.2)<br>**
# **[4.3 Preparing the inference environment](#4.3)<br>**
# **[4.4 Triton Inference Server configuration](#4.4)<br>**
# **[4.5 Launching Triton Inference Server](#4.5)<br>**
# **[4.6 Writing client application consuming our GPT-J model](#4.6)<br>**

# %% [markdown]
# # 4.1 NVIDIA Triton Inference Server

# %% [markdown]
# NVIDIA Triton™ Inference Server, part of the NVIDIA AI platform, is an open-source inference serving software that helps standardize model deployment and execution and delivers fast and scalable AI in production. Triton streamlines AI inference by enabling teams to deploy, run, and scale trained AI models from any framework on any GPU- or CPU-based infrastructure. It provides AI researchers and data scientists the freedom to choose the right framework for their projects without impacting production deployment. It also helps developers deliver high-performance inference across cloud, on-prem, edge, and embedded devices.
# <div style="text-align:center">
# <img src="./images/FT_custom_backend.PNG" style="width: 60%;position:relative;" />
# </div>

# %% [markdown]
# Triton inference server is distributed with a number of execution backends including backends supporting TensorRT, PyTorch, custom Python/C++ backend, HugeCTR, OpenVion and many other including FasterTransformer. It can be extended by developers as new backends can also be integrated. [FasterTransfromer execution backend](https://github.com/triton-inference-server/fastertransformer_backend/) written by NVIDIA allows to deploy models optimized using FasterTransformer library not only in a single GPU but also multi-GPU and multi node mode.

# %% [markdown]
# # 4.2 Overview of the end-to-end inference pipeline

# %% [markdown]
# Before we dive into the Triton deployment process, let us take a bird's eye view of the end-to-end deployment process. In notebook 1, we have completed steps analogous to 1 and 2 but focused on standalone FasterTransformer environment. We need to create a variant of this environment capable of supporting FasterTransformer execution backend for triton. In notebook 3, we have completed steps 3, 4, 5 and 6 so we will be able to reuse the assets produced at those stages. After we execute steps 1 and 2, we just need to execute steps 7 and 8 namely we will focus on configuring Triton Inference server and its execution.

# %% [markdown]
# <div style="text-align:center">
# <img src="./images/FT_TRITON_pipeline_v1.1..PNG" style="width: 70%;position:relative;" />
# </div>

# %% [markdown]
# # 4.3 Preparing the inference environment

# %% [markdown]
# The Fastertransformer_backend for Triton Inference Server is already installed into Triton in our container, so we do not have to deploy it manually. We do need to download `fastertransformer_backend` code from GitHub (https://github.com/triton-inference-server/fastertransformer_backend) to use Triton's configs for GPT-J prepared by NVIDIA. They are placed in <code>fastertransformer_backend/all_models</code>.

# %%
# !git clone https://github.com/triton-inference-server/fastertransformer_backend
# %cd fastertransformer_backend
# !git checkout 571a1fce438409087f5d3889237541828cc24ba5
# %cd ../
# Out:
# Cloning into 'fastertransformer_backend'...
# remote: Enumerating objects: 631, done.
# remote: Counting objects: 100% (281/281), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 631 (delta 164), reused 219 (delta 131), pack-reused 350
# Receiving objects: 100% (631/631), 2.80 MiB | 13.42 MiB/s, done.
# Resolving deltas: 100% (301/301), done.
# /dli/task/fastertransformer_backend
# Note: switching to '571a1fce438409087f5d3889237541828cc24ba5'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 571a1fc Merge v1.1 branch to main branch (#22)
# /dli/task

# %%
# !mkdir triton-model-store
# !cp -r ./fastertransformer_backend/all_models/gptj triton-model-store/

# %% [markdown]
# Let's have a look at the Triton's config for the GPT-J model `./fastertransformer_backend/all_models/gptj`:

# %%
# !ls triton-model-store/gptj/
# Out:
# ensemble  fastertransformer  postprocessing  preprocessing

# %% [markdown]
# This configuration file is a perfect example of model ensemble in Triton Inference Server. Triton is a general purpose inference server allowing not only to run individual neural networks, but also construct complex ensembles/pipelines. These pipelines may contain multiple neural network stages connected with each other into one inference service. Pipelines can be composed of different components. One can add Python/C++ scripts before and/or after any neural network to add any pre/post processing steps that could transform the data into its final format.  </br>
#
# In the `GPT-J` inference pipeline we have three distinct execution steps: </br> `preprocessing` -> `model execution with fastertransformer` -> `postprocessing` </br>
#
# We bring those three pieces together with an `ensemble` defined in Triton configuration file. Overall, the client-server inference scheme looks like this:

# %% [markdown]
# <center><img src="data:image/png;base64,..." width=700px/></center>

# %% [markdown]
# # 4.4 Triton Inference Server configuration

# %% [markdown]
# #### Updating model configuration

# %% [markdown]
# Let's edit the Triton configuration file responsible for the GPT-J model part of our pipeline. We can do that by editing the following file: <b>["triton-model-store/gptj/fastertransformer/config.pbtxt"]("triton-model-store/gptj/fastertransformer/config.pbtxt)</b>
# Only two parameters need to be changed for us to be able to start inference on our environment:<br/>
# Please update `tensor_para_size` to enable two way tensor parallelism.<br/>
# <code>
# parameters {
#   key: "tensor_para_size"
#   value: {
#     string_value: "2"
#   }
# }
# </code> <br/>
# Please update the path to the checkpoint prepared for 2-GPU inference (folder from the previous step). <br/>
# <code>
# parameters {
#   key: "model_checkpoint_path"
#   value: {
#     string_value: "./models/j6b_ckpt/2-gpu/"
#   }
# }
#  </code>

# %% [markdown]
# #### Kernel autotuning

# %% [markdown]
# Consistently to what we have done in the previous notebook in section 3.6.2, we need to prepare execution configuration by executing kernel autotuning.

# %%
# !CUDA_VISIBLE_DEVICES=3  ./FasterTransformer/build/bin/gpt_gemm 1 1 128 16 256 16384 50256 1 2
# Out:
# [INFO] arguments:
#   batch_size: 1
#   beam_width: 1
#   max_input_len: 128
#   head_num: 16
#   size_per_head: 256
#   inter_size: 16384
#   vocab_size: 50256
#   data_type: 1
#   tensor_para_size: 2
#
# Device Graphics Device
# ***Encoder Gemm Testing Begin***
# ***Cublas Gemm Testing Begin***
#
# -----------------------------
# GEMM test 0: [M: 128, K: 4096, N: 6144] context from_tensor * weightQKV
# algo_99 costs 0.052ms
# algo_100 costs 0.044ms
# algo_101 costs 0.044ms
# algo_102 costs 0.044ms
# algo_103 costs 0.044ms
# algo_104 costs 0.044ms
# algo_105 costs 0.044ms
# algo_106 costs 0.044ms
# algo_107 costs 0.044ms
# algo_108 costs 0.044ms
# algo_109 costs 0.044ms
# algo_110 costs 0.044ms
# algo_111 costs 0.044ms
# algo_112 costs 0.044ms
# algo_113 costs 0.044ms
# algo_114 costs 0.044ms
# algo_115 costs 0.044ms
# fast_algo 102 costs 0.044 ms
# ***cublasLt Gemm Testing Beign***
# AlgoCount: 3813
# return 1 and run heuristic algo
# workspacesize==0, run 170 algos
# result 000 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=16} status 0 time 0.043223ms workspace=0 mathMode=0 waves=0.888889
# result 001 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=16} status 0 time 0.043418ms workspace=0 mathMode=0 waves=0.888889
# result 002 : algo={ Id=21, tileIdx=18 (128x64) splitK=1 reduc=0 swizzle=0 custom=0 stages=18} status 0 time 0.043663ms workspace=0 mathMode=0 waves=0.888889
# result 003 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=12} status 0 time 0.043848ms workspace=0 mathMode=0 waves=0.444444
# result 004 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=12} status 0 time 0.044114ms workspace=0 mathMode=0 waves=0.444444
# result 005 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.045896ms workspace=0 mathMode=0 waves=0.444444
# result 006 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.046684ms workspace=0 mathMode=0 waves=0.444444
# result 007 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=11} status 0 time 0.055716ms workspace=0 mathMode=0 waves=0.222222
# result 008 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=11} status 0 time 0.055747ms workspace=0 mathMode=0 waves=0.222222
# result 009 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.055859ms workspace=0 mathMode=0 waves=0.444444
# result 010 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.055921ms workspace=0 mathMode=0 waves=0.444444
# result 011 : algo={ Id=6, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=9} status 0 time 0.102185ms workspace=0 mathMode=0 waves=0.222222
# result 012 : algo={ Id=6, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.102758ms workspace=0 mathMode=0 waves=0.222222
# result 013 : algo={ Id=6, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.102769ms workspace=0 mathMode=0 waves=0.222222
# result 014 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.103250ms workspace=0 mathMode=0 waves=0.444444
# result 015 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.103260ms workspace=0 mathMode=0 waves=0.444444
# result 016 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.104786ms workspace=0 mathMode=0 waves=0.222222
# result 017 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.104806ms workspace=0 mathMode=0 waves=0.222222
# result 018 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.113480ms workspace=0 mathMode=0 waves=0.222222
# result 019 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.113644ms workspace=0 mathMode=0 waves=0.222222
# result 020 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.120279ms workspace=0 mathMode=0 waves=0.222222
# result 021 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.120371ms workspace=0 mathMode=0 waves=0.222222
# result 022 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.120812ms workspace=0 mathMode=0 waves=0.444444
# result 023 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.120822ms workspace=0 mathMode=0 waves=0.444444
# result 024 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.126249ms workspace=0 mathMode=0 waves=0.444444
# result 025 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.126290ms workspace=0 mathMode=0 waves=0.444444
# result 026 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.127416ms workspace=0 mathMode=0 waves=0.222222
# result 027 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.127539ms workspace=0 mathMode=0 waves=0.222222
# result 028 : algo={ Id=5, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.132147ms workspace=0 mathMode=0 waves=0.222222
# result 029 : algo={ Id=5, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.132168ms workspace=0 mathMode=0 waves=0.222222
# result 030 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.135823ms workspace=0 mathMode=0 waves=0.444444
# result 031 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.135854ms workspace=0 mathMode=0 waves=0.444444
# result 032 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.146708ms workspace=0 mathMode=0 waves=0.222222
# result 033 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.146708ms workspace=0 mathMode=0 waves=0.222222
# result 034 : algo={ Id=1, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.405197ms workspace=0 mathMode=0 waves=1.777778
# result 035 : algo={ Id=1, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.405217ms workspace=0 mathMode=0 waves=1.777778
# result 036 : algo={ Id=0, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.416922ms workspace=0 mathMode=0 waves=0.444444
# result 037 : algo={ Id=0, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.419113ms workspace=0 mathMode=0 waves=0.444444
# result 038 : algo={ Id=1, tileIdx=13 (64x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.422236ms workspace=0 mathMode=0 waves=1.777778
# result 039 : algo={ Id=0, tileIdx=14 (32x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.450058ms workspace=0 mathMode=0 waves=0.444444
# result 040 : algo={ Id=0, tileIdx=14 (32x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.450181ms workspace=0 mathMode=0 waves=0.444444
# result 041 : algo={ Id=1, tileIdx=11 (32x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.450283ms workspace=0 mathMode=0 waves=1.777778
# result 042 : algo={ Id=1, tileIdx=11 (32x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.452332ms workspace=0 mathMode=0 waves=1.777778
# result 043 : algo={ Id=0, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.476785ms workspace=0 mathMode=0 waves=0.222222
# result 044 : algo={ Id=1, tileIdx=13 (64x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.479560ms workspace=0 mathMode=0 waves=1.777778
# result 045 : algo={ Id=0, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.480010ms workspace=0 mathMode=0 waves=0.222222
# result 046 : algo={ Id=0, tileIdx=15 (64x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.503736ms workspace=0 mathMode=0 waves=0.222222
# result 047 : algo={ Id=0, tileIdx=15 (64x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.515942ms workspace=0 mathMode=0 waves=0.222222
# result 048 : algo={ Id=0, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.762481ms workspace=0 mathMode=0 waves=0.222222
# result 049 : algo={ Id=0, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.762501ms workspace=0 mathMode=0 waves=0.222222
# algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=16} status 0 time 0.043223ms workspace=0 mathMode=0 waves=0.888889
# ***cublasLt Gemm Testing End***
#
# -----------------------------
# GEMM test 1: [M: 128, K: 256, N: 128] context batch gemm Q*K^T
# algo_99 costs 0.009ms
# algo_100 costs 0.008ms
# algo_101 costs 0.008ms
# algo_102 costs 0.008ms
# algo_103 costs 0.007ms
# algo_104 costs 0.006ms
# algo_105 costs 0.006ms
# algo_106 costs 0.006ms
# algo_107 costs 0.006ms
# algo_108 costs 0.008ms
# algo_109 costs 0.007ms
# algo_110 costs 0.007ms
# algo_111 costs 0.006ms
# algo_112 costs 0.006ms
# algo_113 costs 0.006ms
# algo_114 costs 0.006ms
# algo_115 costs 0.006ms
# fast_algo 105 costs 0.006 ms
#
# -----------------------------
# GEMM test 2: [M: 128, K: 128, N: 256] context batch gemm QK*V^T
# algo_99 costs 0.006ms
# algo_100 costs 0.006ms
# algo_101 costs 0.006ms
# algo_102 costs 0.006ms
# algo_103 costs 0.006ms
# algo_104 costs 0.006ms
# algo_105 costs 0.006ms
# algo_106 costs 0.006ms
# algo_107 costs 0.006ms
# algo_108 costs 0.006ms
# algo_109 costs 0.006ms
# algo_110 costs 0.006ms
# algo_111 costs 0.006ms
# algo_112 costs 0.006ms
# algo_113 costs 0.007ms
# algo_114 costs 0.007ms
# algo_115 costs 0.008ms
# fast_algo 112 costs 0.006 ms
#
# -----------------------------
# GEMM test 3: [M: 128, K: 2048, N: 4096] context attr * output_kernel
# algo_99 costs 0.019ms
# algo_100 costs 0.019ms
# algo_101 costs 0.019ms
# algo_102 costs 0.019ms
# algo_103 costs 0.019ms
# algo_104 costs 0.019ms
# algo_105 costs 0.019ms
# algo_106 costs 0.019ms
# algo_107 costs 0.019ms
# algo_108 costs 0.019ms
# algo_109 costs 0.019ms
# algo_110 costs 0.019ms
# algo_111 costs 0.019ms
# algo_112 costs 0.019ms
# algo_113 costs 0.019ms
# algo_114 costs 0.019ms
# algo_115 costs 0.019ms
# fast_algo 101 costs 0.019 ms
# ***cublasLt Gemm Testing Beign***
# AlgoCount: 4287
# return 1 and run heuristic algo
# workspacesize==0, run 170 algos
# result 000 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=16} status 0 time 0.018053ms workspace=0 mathMode=0 waves=0.592593
# result 001 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=16} status 0 time 0.018074ms workspace=0 mathMode=0 waves=0.592593
# result 002 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.018074ms workspace=0 mathMode=0 waves=0.296296
# result 003 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=12} status 0 time 0.018094ms workspace=0 mathMode=0 waves=0.296296
# result 004 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=12} status 0 time 0.018094ms workspace=0 mathMode=0 waves=0.296296
# result 005 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.018115ms workspace=0 mathMode=0 waves=0.296296
# result 006 : algo={ Id=21, tileIdx=18 (128x64) splitK=1 reduc=0 swizzle=0 custom=0 stages=18} status 0 time 0.018790ms workspace=0 mathMode=0 waves=0.592593
# result 007 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=11} status 0 time 0.030751ms workspace=0 mathMode=0 waves=0.148148
# result 008 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=11} status 0 time 0.030761ms workspace=0 mathMode=0 waves=0.148148
# result 009 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.030781ms workspace=0 mathMode=0 waves=0.296296
# result 010 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.030781ms workspace=0 mathMode=0 waves=0.296296
# result 011 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.044083ms workspace=0 mathMode=0 waves=0.148148
# result 012 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.044114ms workspace=0 mathMode=0 waves=0.148148
# result 013 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.053893ms workspace=0 mathMode=0 waves=0.148148
# result 014 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.053934ms workspace=0 mathMode=0 waves=0.148148
# result 015 : algo={ Id=6, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=9} status 0 time 0.054180ms workspace=0 mathMode=0 waves=0.148148
# result 016 : algo={ Id=6, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.054620ms workspace=0 mathMode=0 waves=0.148148
# result 017 : algo={ Id=6, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.054641ms workspace=0 mathMode=0 waves=0.148148
# result 018 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.054948ms workspace=0 mathMode=0 waves=0.296296
# result 019 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.054999ms workspace=0 mathMode=0 waves=0.296296
# result 020 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.055962ms workspace=0 mathMode=0 waves=0.296296
# result 021 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.055972ms workspace=0 mathMode=0 waves=0.296296
# result 022 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.057119ms workspace=0 mathMode=0 waves=0.148148
# result 023 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.057149ms workspace=0 mathMode=0 waves=0.148148
# result 024 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.057324ms workspace=0 mathMode=0 waves=0.148148
# result 025 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.057395ms workspace=0 mathMode=0 waves=0.148148
# result 026 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.057600ms workspace=0 mathMode=0 waves=0.148148
# result 027 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.057610ms workspace=0 mathMode=0 waves=0.148148
# result 028 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.067021ms workspace=0 mathMode=0 waves=0.296296
# result 029 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.067041ms workspace=0 mathMode=0 waves=0.296296
# result 030 : algo={ Id=5, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.067656ms workspace=0 mathMode=0 waves=0.148148
# result 031 : algo={ Id=5, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.067676ms workspace=0 mathMode=0 waves=0.148148
# result 032 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.068065ms workspace=0 mathMode=0 waves=0.296296
# result 033 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.068096ms workspace=0 mathMode=0 waves=0.296296
# result 034 : algo={ Id=1, tileIdx=11 (32x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.145347ms workspace=0 mathMode=0 waves=1.185185
# result 035 : algo={ Id=1, tileIdx=11 (32x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.145377ms workspace=0 mathMode=0 waves=1.185185
# result 036 : algo={ Id=1, tileIdx=13 (64x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.155331ms workspace=0 mathMode=0 waves=1.185185
# result 037 : algo={ Id=1, tileIdx=13 (64x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.155351ms workspace=0 mathMode=0 waves=1.185185
# result 038 : algo={ Id=0, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.203919ms workspace=0 mathMode=0 waves=0.296296
# result 039 : algo={ Id=0, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.204186ms workspace=0 mathMode=0 waves=0.296296
# result 040 : algo={ Id=1, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.206756ms workspace=0 mathMode=0 waves=1.185185
# result 041 : algo={ Id=1, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.206766ms workspace=0 mathMode=0 waves=1.185185
# result 042 : algo={ Id=0, tileIdx=14 (32x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.211722ms workspace=0 mathMode=0 waves=0.296296
# result 043 : algo={ Id=0, tileIdx=14 (32x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.211804ms workspace=0 mathMode=0 waves=0.296296
# result 044 : algo={ Id=0, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.215880ms workspace=0 mathMode=0 waves=0.148148
# result 045 : algo={ Id=0, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.215941ms workspace=0 mathMode=0 waves=0.148148
# result 046 : algo={ Id=0, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.384246ms workspace=0 mathMode=0 waves=0.148148
# result 047 : algo={ Id=0, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.384266ms workspace=0 mathMode=0 waves=0.148148
# result 048 : algo={ Id=0, tileIdx=15 (64x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.392069ms workspace=0 mathMode=0 waves=0.148148
# result 049 : algo={ Id=0, tileIdx=15 (64x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.392090ms workspace=0 mathMode=0 waves=0.148148
# algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=16} status 0 time 0.018053ms workspace=0 mathMode=0 waves=0.592593
# ***cublasLt Gemm Testing End***
#
# -----------------------------
# GEMM test 4: [M: 128, K: 4096, N: 8192] context ffn gemm 1
# algo_99 costs 0.057ms
# algo_100 costs 0.057ms
# algo_101 costs 0.057ms
# algo_102 costs 0.057ms
# algo_103 costs 0.057ms
# algo_104 costs 0.057ms
# algo_105 costs 0.057ms
# algo_106 costs 0.057ms
# algo_107 costs 0.057ms
# algo_108 costs 0.057ms
# algo_109 costs 0.057ms
# algo_110 costs 0.057ms
# algo_111 costs 0.057ms
# algo_112 costs 0.057ms
# algo_113 costs 0.057ms
# algo_114 costs 0.057ms
# algo_115 costs 0.057ms
# fast_algo 102 costs 0.057 ms
# ***cublasLt Gemm Testing Beign***
# AlgoCount: 3813
# return 2 and run heuristic algo
# workspacesize==0, run 170 algos
# result 000 : algo={ Id=6, tileIdx=21 (256x64) splitK=1 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.056801ms workspace=0 mathMode=0 waves=0.592593
# result 001 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=11} status 0 time 0.057272ms workspace=0 mathMode=0 waves=0.296296
# result 002 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=11} status 0 time 0.057313ms workspace=0 mathMode=0 waves=0.296296
# result 003 : algo={ Id=6, tileIdx=20 (128x128) splitK=1 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.060508ms workspace=0 mathMode=0 waves=0.592593
# result 004 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.060580ms workspace=0 mathMode=0 waves=0.592593
# result 005 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.060713ms workspace=0 mathMode=0 waves=0.592593
# result 006 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.062505ms workspace=0 mathMode=0 waves=0.592593
# result 007 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.063130ms workspace=0 mathMode=0 waves=0.592593
# result 008 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=12} status 0 time 0.065894ms workspace=0 mathMode=0 waves=0.592593
# result 009 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=12} status 0 time 0.067666ms workspace=0 mathMode=0 waves=0.592593
# result 010 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=16} status 0 time 0.074598ms workspace=0 mathMode=0 waves=1.185185
# result 011 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=16} status 0 time 0.074660ms workspace=0 mathMode=0 waves=1.185185
# result 012 : algo={ Id=6, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.102789ms workspace=0 mathMode=0 waves=0.296296
# result 013 : algo={ Id=6, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.102810ms workspace=0 mathMode=0 waves=0.296296
# result 014 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.103557ms workspace=0 mathMode=0 waves=0.592593
# result 015 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.103567ms workspace=0 mathMode=0 waves=0.592593
# result 016 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.108308ms workspace=0 mathMode=0 waves=0.296296
# result 017 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.108380ms workspace=0 mathMode=0 waves=0.296296
# result 018 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.114565ms workspace=0 mathMode=0 waves=0.296296
# result 019 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.114678ms workspace=0 mathMode=0 waves=0.296296
# result 020 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.118845ms workspace=0 mathMode=0 waves=0.296296
# result 021 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.119081ms workspace=0 mathMode=0 waves=0.296296
# result 022 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.125276ms workspace=0 mathMode=0 waves=0.592593
# result 023 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.125307ms workspace=0 mathMode=0 waves=0.592593
# result 024 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.127242ms workspace=0 mathMode=0 waves=0.592593
# result 025 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.127273ms workspace=0 mathMode=0 waves=0.592593
# result 026 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.131348ms workspace=0 mathMode=0 waves=0.296296
# result 027 : algo={ Id=5, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.133642ms workspace=0 mathMode=0 waves=0.296296
# result 028 : algo={ Id=5, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.133652ms workspace=0 mathMode=0 waves=0.296296
# result 029 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.134584ms workspace=0 mathMode=0 waves=0.296296
# result 030 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.135670ms workspace=0 mathMode=0 waves=0.592593
# result 031 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.135711ms workspace=0 mathMode=0 waves=0.592593
# result 032 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.146360ms workspace=0 mathMode=0 waves=0.296296
# result 033 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.146668ms workspace=0 mathMode=0 waves=0.296296
# result 034 : algo={ Id=1, tileIdx=13 (64x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.518769ms workspace=0 mathMode=0 waves=2.370370
# result 035 : algo={ Id=1, tileIdx=13 (64x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.524145ms workspace=0 mathMode=0 waves=2.370370
# result 036 : algo={ Id=1, tileIdx=11 (32x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.561132ms workspace=0 mathMode=0 waves=2.370370
# result 037 : algo={ Id=1, tileIdx=11 (32x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.576850ms workspace=0 mathMode=0 waves=2.370370
# result 038 : algo={ Id=1, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.605245ms workspace=0 mathMode=0 waves=2.370370
# result 039 : algo={ Id=1, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.653916ms workspace=0 mathMode=0 waves=2.370370
# result 040 : algo={ Id=0, tileIdx=14 (32x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.680735ms workspace=0 mathMode=0 waves=0.592593
# result 041 : algo={ Id=0, tileIdx=14 (32x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.680847ms workspace=0 mathMode=0 waves=0.592593
# result 042 : algo={ Id=0, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.689500ms workspace=0 mathMode=0 waves=0.592593
# result 043 : algo={ Id=0, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.692613ms workspace=0 mathMode=0 waves=0.592593
# result 044 : algo={ Id=0, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.762829ms workspace=0 mathMode=0 waves=0.296296
# result 045 : algo={ Id=0, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.762849ms workspace=0 mathMode=0 waves=0.296296
# result 046 : algo={ Id=0, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.782039ms workspace=0 mathMode=0 waves=0.296296
# result 047 : algo={ Id=0, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.788490ms workspace=0 mathMode=0 waves=0.296296
# result 048 : algo={ Id=0, tileIdx=15 (64x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.800952ms workspace=0 mathMode=0 waves=0.296296
# result 049 : algo={ Id=0, tileIdx=15 (64x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.802130ms workspace=0 mathMode=0 waves=0.296296
# algo={ Id=6, tileIdx=21 (256x64) splitK=1 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.056801ms workspace=0 mathMode=0 waves=0.592593
# ***cublasLt Gemm Testing End***
#
# -----------------------------
# GEMM test 5: [M: 128, K: 8192, N: 4096] context ffn gemm 2
# algo_99 costs 0.062ms
# algo_100 costs 0.061ms
# algo_101 costs 0.061ms
# algo_102 costs 0.061ms
# algo_103 costs 0.061ms
# algo_104 costs 0.061ms
# algo_105 costs 0.061ms
# algo_106 costs 0.061ms
# algo_107 costs 0.061ms
# algo_108 costs 0.061ms
# algo_109 costs 0.061ms
# algo_110 costs 0.061ms
# algo_111 costs 0.061ms
# algo_112 costs 0.061ms
# algo_113 costs 0.061ms
# algo_114 costs 0.061ms
# algo_115 costs 0.061ms
# fast_algo 103 costs 0.061 ms
# ***cublasLt Gemm Testing Beign***
# AlgoCount: 4287
# return 7 and run heuristic algo
# workspacesize==0, run 170 algos
# result 000 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=12} status 0 time 0.057928ms workspace=0 mathMode=0 waves=0.296296
# result 001 : algo={ Id=6, tileIdx=17 (64x128) splitK=1 reduc=0 swizzle=0 custom=0 stages=16} status 0 time 0.062894ms workspace=0 mathMode=0 waves=0.592593
# result 002 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.072755ms workspace=0 mathMode=0 waves=0.296296
# result 003 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.072888ms workspace=0 mathMode=0 waves=0.296296
# result 004 : algo={ Id=6, tileIdx=17 (64x128) splitK=3 reduc=4 swizzle=0 custom=0 stages=16} status 0 time 0.073533ms workspace=3145728 mathMode=0 waves=1.777778
# result 005 : algo={ Id=6, tileIdx=24 (256x128) splitK=5 reduc=1 swizzle=1 custom=0 stages=15} status 0 time 0.075776ms workspace=64 mathMode=0 waves=0.740741
# result 006 : algo={ Id=6, tileIdx=24 (256x128) splitK=4 reduc=1 swizzle=1 custom=0 stages=15} status 0 time 0.076861ms workspace=64 mathMode=0 waves=0.592593
# result 007 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.103219ms workspace=0 mathMode=0 waves=0.296296
# result 008 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.103229ms workspace=0 mathMode=0 waves=0.296296
# result 009 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=11} status 0 time 0.103782ms workspace=0 mathMode=0 waves=0.148148
# result 010 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=11} status 0 time 0.103823ms workspace=0 mathMode=0 waves=0.148148
# result 011 : algo={ Id=6, tileIdx=20 (128x128) splitK=1 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.107674ms workspace=0 mathMode=0 waves=0.296296
# result 012 : algo={ Id=23, tileIdx=20 (128x128) splitK=2 reduc=4 swizzle=0 custom=0 stages=15} status 0 time 0.109947ms workspace=2097152 mathMode=0 waves=0.592593
# result 013 : algo={ Id=6, tileIdx=23 (128x256) splitK=2 reduc=1 swizzle=1 custom=0 stages=15} status 0 time 0.115313ms workspace=128 mathMode=0 waves=0.592593
# result 014 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.198011ms workspace=0 mathMode=0 waves=0.148148
# result 015 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.198011ms workspace=0 mathMode=0 waves=0.148148
# result 016 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.198011ms workspace=0 mathMode=0 waves=0.296296
# result 017 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.198031ms workspace=0 mathMode=0 waves=0.296296
# result 018 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.216177ms workspace=0 mathMode=0 waves=0.148148
# result 019 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.216637ms workspace=0 mathMode=0 waves=0.148148
# result 020 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.221297ms workspace=0 mathMode=0 waves=0.296296
# result 021 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.221389ms workspace=0 mathMode=0 waves=0.296296
# result 022 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.222423ms workspace=0 mathMode=0 waves=0.148148
# result 023 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.222648ms workspace=0 mathMode=0 waves=0.148148
# result 024 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.233667ms workspace=0 mathMode=0 waves=0.148148
# result 025 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.234209ms workspace=0 mathMode=0 waves=0.148148
# result 026 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.245422ms workspace=0 mathMode=0 waves=0.296296
# result 027 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.245422ms workspace=0 mathMode=0 waves=0.296296
# result 028 : algo={ Id=5, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.257034ms workspace=0 mathMode=0 waves=0.148148
# result 029 : algo={ Id=5, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.257044ms workspace=0 mathMode=0 waves=0.148148
# result 030 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.259676ms workspace=0 mathMode=0 waves=0.296296
# result 031 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.259697ms workspace=0 mathMode=0 waves=0.296296
# result 032 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.278743ms workspace=0 mathMode=0 waves=0.148148
# result 033 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.281037ms workspace=0 mathMode=0 waves=0.148148
# result 034 : algo={ Id=1, tileIdx=11 (32x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.615229ms workspace=0 mathMode=0 waves=1.185185
# result 035 : algo={ Id=1, tileIdx=13 (64x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.630006ms workspace=0 mathMode=0 waves=1.185185
# result 036 : algo={ Id=1, tileIdx=11 (32x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.635802ms workspace=0 mathMode=0 waves=1.185185
# result 037 : algo={ Id=1, tileIdx=13 (64x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.643266ms workspace=0 mathMode=0 waves=1.185185
# result 038 : algo={ Id=1, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.796877ms workspace=0 mathMode=0 waves=1.185185
# result 039 : algo={ Id=1, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.797071ms workspace=0 mathMode=0 waves=1.185185
# result 040 : algo={ Id=0, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.847053ms workspace=0 mathMode=0 waves=0.296296
# result 041 : algo={ Id=0, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.851087ms workspace=0 mathMode=0 waves=0.296296
# result 042 : algo={ Id=0, tileIdx=14 (32x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.895263ms workspace=0 mathMode=0 waves=0.296296
# result 043 : algo={ Id=0, tileIdx=14 (32x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.895457ms workspace=0 mathMode=0 waves=0.296296
# result 044 : algo={ Id=0, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.935854ms workspace=0 mathMode=0 waves=0.148148
# result 045 : algo={ Id=0, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.936264ms workspace=0 mathMode=0 waves=0.148148
# result 046 : algo={ Id=0, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 1.516728ms workspace=0 mathMode=0 waves=0.148148
# result 047 : algo={ Id=0, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 1.516790ms workspace=0 mathMode=0 waves=0.148148
# result 048 : algo={ Id=0, tileIdx=15 (64x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 1.549261ms workspace=0 mathMode=0 waves=0.148148
# result 049 : algo={ Id=0, tileIdx=15 (64x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 1.549967ms workspace=0 mathMode=0 waves=0.148148
# algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=12} status 0 time 0.057928ms workspace=0 mathMode=0 waves=0.296296
# ***cublasLt Gemm Testing End***
#
# -----------------------------
# GEMM test 6: [M: 1, K: 4096, N: 6144] from_tensor * weightQKV
# algo_99 costs 0.043ms
# algo_100 costs 0.042ms
# algo_101 costs 0.042ms
# algo_102 costs 0.042ms
# algo_103 costs 0.042ms
# algo_104 costs 0.042ms
# algo_105 costs 0.042ms
# algo_106 costs 0.042ms
# algo_107 costs 0.042ms
# algo_108 costs 0.042ms
# algo_109 costs 0.042ms
# algo_110 costs 0.042ms
# algo_111 costs 0.042ms
# algo_112 costs 0.042ms
# algo_113 costs 0.042ms
# algo_114 costs 0.042ms
# algo_115 costs 0.042ms
# fast_algo 113 costs 0.042 ms
# ***cublasLt Gemm Testing Beign***
# AlgoCount: 5000
# return 8 and run heuristic algo
# workspacesize==0, run 245 algos
# result 000 : algo={ Id=6, tileIdx=15 (64x64) splitK=1 reduc=0 swizzle=1 custom=0 stages=18} status 0 time 0.038605ms workspace=0 mathMode=0 waves=0.888889
# result 001 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.039660ms workspace=0 mathMode=0 waves=0.222222
# result 002 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.039660ms workspace=0 mathMode=0 waves=0.222222
# result 003 : algo={ Id=31, tileIdx=15 (64x64) splitK=1 reduc=0 swizzle=0 custom=0 stages=17} status 0 time 0.039670ms workspace=0 mathMode=0 waves=0.444444
# result 004 : algo={ Id=6, tileIdx=18 (128x64) splitK=4 reduc=4 swizzle=1 custom=0 stages=12} status 0 time 0.041308ms workspace=49152 mathMode=0 waves=0.888889
# result 005 : algo={ Id=6, tileIdx=18 (128x64) splitK=2 reduc=1 swizzle=1 custom=0 stages=12} status 0 time 0.041564ms workspace=192 mathMode=0 waves=0.444444
# result 006 : algo={ Id=21, tileIdx=21 (256x64) splitK=4 reduc=4 swizzle=0 custom=0 stages=10} status 0 time 0.042127ms workspace=49152 mathMode=0 waves=0.444444
# result 007 : algo={ Id=6, tileIdx=18 (128x64) splitK=3 reduc=4 swizzle=0 custom=0 stages=16} status 0 time 0.043377ms workspace=36864 mathMode=0 waves=1.333333
# result 008 : algo={ Id=6, tileIdx=18 (128x64) splitK=7 reduc=1 swizzle=0 custom=0 stages=16} status 0 time 0.046305ms workspace=192 mathMode=0 waves=3.111111
# result 009 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.055214ms workspace=0 mathMode=0 waves=0.444444
# result 010 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.055224ms workspace=0 mathMode=0 waves=0.444444
# result 011 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=11} status 0 time 0.055347ms workspace=0 mathMode=0 waves=0.222222
# result 012 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=11} status 0 time 0.055357ms workspace=0 mathMode=0 waves=0.222222
# result 013 : algo={ Id=13, tileIdx=0 (UNDEF) splitK=64 reduc=2 swizzle=0 custom=7 stages=0} status 0 time 0.061676ms workspace=1572880 mathMode=0 waves=2.844445
# result 014 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.102400ms workspace=0 mathMode=0 waves=0.222222
# result 015 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.102400ms workspace=0 mathMode=0 waves=0.222222
# result 016 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.102984ms workspace=0 mathMode=0 waves=0.444444
# result 017 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.103004ms workspace=0 mathMode=0 waves=0.444444
# result 018 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.109394ms workspace=0 mathMode=0 waves=0.222222
# result 019 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.109476ms workspace=0 mathMode=0 waves=0.222222
# result 020 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.109926ms workspace=0 mathMode=0 waves=0.444444
# result 021 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.109957ms workspace=0 mathMode=0 waves=0.444444
# result 022 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.112927ms workspace=0 mathMode=0 waves=0.111111
# result 023 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.113213ms workspace=0 mathMode=0 waves=0.111111
# result 024 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.123965ms workspace=0 mathMode=0 waves=0.111111
# result 025 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.124017ms workspace=0 mathMode=0 waves=0.111111
# result 026 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.125635ms workspace=0 mathMode=0 waves=0.444444
# result 027 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.125635ms workspace=0 mathMode=0 waves=0.444444
# result 028 : algo={ Id=5, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.126700ms workspace=0 mathMode=0 waves=0.222222
# result 029 : algo={ Id=5, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.126771ms workspace=0 mathMode=0 waves=0.222222
# result 030 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.127222ms workspace=0 mathMode=0 waves=0.444444
# result 031 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.127222ms workspace=0 mathMode=0 waves=0.444444
# result 032 : algo={ Id=1, tileIdx=13 (64x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.141107ms workspace=0 mathMode=0 waves=0.444444
# result 033 : algo={ Id=1, tileIdx=13 (64x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.141128ms workspace=0 mathMode=0 waves=0.444444
# result 034 : algo={ Id=1, tileIdx=11 (32x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.141527ms workspace=0 mathMode=0 waves=0.444444
# result 035 : algo={ Id=1, tileIdx=11 (32x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.141548ms workspace=0 mathMode=0 waves=0.444444
# result 036 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.147763ms workspace=0 mathMode=0 waves=0.111111
# result 037 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.147814ms workspace=0 mathMode=0 waves=0.111111
# result 038 : algo={ Id=1, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.204012ms workspace=0 mathMode=0 waves=0.444444
# result 039 : algo={ Id=1, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.204032ms workspace=0 mathMode=0 waves=0.444444
# result 040 : algo={ Id=0, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.380283ms workspace=0 mathMode=0 waves=0.111111
# result 041 : algo={ Id=0, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.380467ms workspace=0 mathMode=0 waves=0.111111
# result 042 : algo={ Id=0, tileIdx=14 (32x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.436224ms workspace=0 mathMode=0 waves=0.444444
# result 043 : algo={ Id=0, tileIdx=14 (32x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.436388ms workspace=0 mathMode=0 waves=0.444444
# result 044 : algo={ Id=0, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.467016ms workspace=0 mathMode=0 waves=0.111111
# result 045 : algo={ Id=0, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.467067ms workspace=0 mathMode=0 waves=0.111111
# result 046 : algo={ Id=0, tileIdx=15 (64x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.477819ms workspace=0 mathMode=0 waves=0.111111
# result 047 : algo={ Id=0, tileIdx=15 (64x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.478044ms workspace=0 mathMode=0 waves=0.111111
# result 048 : algo={ Id=0, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.760504ms workspace=0 mathMode=0 waves=0.222222
# result 049 : algo={ Id=0, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.760545ms workspace=0 mathMode=0 waves=0.222222
# algo={ Id=6, tileIdx=15 (64x64) splitK=1 reduc=0 swizzle=1 custom=0 stages=18} status 0 time 0.038605ms workspace=0 mathMode=0 waves=0.888889
# ***cublasLt Gemm Testing End***
#
# -----------------------------
# GEMM test 7: [M: 1, K: 2048, N: 4096] attr * output_kernel
# algo_99 costs 0.018ms
# algo_100 costs 0.013ms
# algo_101 costs 0.012ms
# algo_102 costs 0.012ms
# algo_103 costs 0.012ms
# algo_104 costs 0.012ms
# algo_105 costs 0.012ms
# algo_106 costs 0.012ms
# algo_107 costs 0.012ms
# algo_108 costs 0.013ms
# algo_109 costs 0.012ms
# algo_110 costs 0.013ms
# algo_111 costs 0.012ms
# algo_112 costs 0.012ms
# algo_113 costs 0.012ms
# algo_114 costs 0.012ms
# algo_115 costs 0.012ms
# fast_algo 101 costs 0.012 ms
# ***cublasLt Gemm Testing Beign***
# AlgoCount: 5000
# return 8 and run heuristic algo
# workspacesize==0, run 245 algos
# result 000 : algo={ Id=31, tileIdx=15 (64x64) splitK=1 reduc=0 swizzle=0 custom=0 stages=17} status 0 time 0.012339ms workspace=0 mathMode=0 waves=0.296296
# result 001 : algo={ Id=6, tileIdx=18 (128x64) splitK=3 reduc=4 swizzle=0 custom=0 stages=16} status 0 time 0.013640ms workspace=24576 mathMode=0 waves=0.888889
# result 002 : algo={ Id=6, tileIdx=15 (64x64) splitK=1 reduc=0 swizzle=1 custom=0 stages=18} status 0 time 0.013773ms workspace=0 mathMode=0 waves=0.592593
# result 003 : algo={ Id=6, tileIdx=18 (128x64) splitK=4 reduc=4 swizzle=1 custom=0 stages=12} status 0 time 0.015872ms workspace=32768 mathMode=0 waves=0.592593
# result 004 : algo={ Id=6, tileIdx=18 (128x64) splitK=2 reduc=1 swizzle=1 custom=0 stages=12} status 0 time 0.016282ms workspace=128 mathMode=0 waves=0.296296
# result 005 : algo={ Id=21, tileIdx=21 (256x64) splitK=4 reduc=4 swizzle=0 custom=0 stages=10} status 0 time 0.016394ms workspace=32768 mathMode=0 waves=0.296296
# result 006 : algo={ Id=13, tileIdx=0 (UNDEF) splitK=32 reduc=2 swizzle=0 custom=7 stages=0} status 0 time 0.017162ms workspace=524304 mathMode=0 waves=0.948148
# result 007 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.017654ms workspace=0 mathMode=0 waves=0.148148
# result 008 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.017695ms workspace=0 mathMode=0 waves=0.148148
# result 009 : algo={ Id=6, tileIdx=18 (128x64) splitK=7 reduc=1 swizzle=0 custom=0 stages=16} status 0 time 0.025498ms workspace=128 mathMode=0 waves=2.074074
# result 010 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.030505ms workspace=0 mathMode=0 waves=0.296296
# result 011 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.030505ms workspace=0 mathMode=0 waves=0.296296
# result 012 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=11} status 0 time 0.030505ms workspace=0 mathMode=0 waves=0.148148
# result 013 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=11} status 0 time 0.030525ms workspace=0 mathMode=0 waves=0.148148
# result 014 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.039096ms workspace=0 mathMode=0 waves=0.074074
# result 015 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.039158ms workspace=0 mathMode=0 waves=0.074074
# result 016 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.053750ms workspace=0 mathMode=0 waves=0.148148
# result 017 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.053801ms workspace=0 mathMode=0 waves=0.148148
# ...
# result 008 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.055603ms workspace=0 mathMode=0 waves=0.592593
# result 009 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=11} status 0 time 0.055706ms workspace=0 mathMode=0 waves=0.296296
# result 010 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=11} status 0 time 0.055706ms workspace=0 mathMode=0 waves=0.296296
# result 011 : algo={ Id=21, tileIdx=21 (256x64) splitK=4 reduc=4 swizzle=0 custom=0 stages=10} status 0 time 0.058266ms workspace=65536 mathMode=0 waves=0.592593
# result 012 : algo={ Id=13, tileIdx=0 (UNDEF) splitK=1 reduc=0 swizzle=0 custom=103 stages=0} status 0 time 0.067953ms workspace=0 mathMode=0 waves=0.592593
# result 013 : algo={ Id=13, tileIdx=0 (UNDEF) splitK=32 reduc=2 swizzle=0 custom=7 stages=0} status 0 time 0.071076ms workspace=1048592 mathMode=0 waves=1.896296
# result 014 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.102615ms workspace=0 mathMode=0 waves=0.296296
# result 015 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.102646ms workspace=0 mathMode=0 waves=0.296296
# result 016 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.103383ms workspace=0 mathMode=0 waves=0.592593
# result 017 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.103404ms workspace=0 mathMode=0 waves=0.592593
# result 018 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.109322ms workspace=0 mathMode=0 waves=0.592593
# result 019 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.109343ms workspace=0 mathMode=0 waves=0.592593
# result 020 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.109711ms workspace=0 mathMode=0 waves=0.296296
# result 021 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.109752ms workspace=0 mathMode=0 waves=0.296296
# result 022 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.113469ms workspace=0 mathMode=0 waves=0.148148
# result 023 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.113490ms workspace=0 mathMode=0 waves=0.148148
# result 024 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.120279ms workspace=0 mathMode=0 waves=0.148148
# result 025 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.120300ms workspace=0 mathMode=0 waves=0.148148
# result 026 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.125809ms workspace=0 mathMode=0 waves=0.592593
# result 027 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.125819ms workspace=0 mathMode=0 waves=0.592593
# result 028 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.127242ms workspace=0 mathMode=0 waves=0.592593
# result 029 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.127293ms workspace=0 mathMode=0 waves=0.592593
# result 030 : algo={ Id=5, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.127345ms workspace=0 mathMode=0 waves=0.296296
# result 031 : algo={ Id=5, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.127365ms workspace=0 mathMode=0 waves=0.296296
# result 032 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.146207ms workspace=0 mathMode=0 waves=0.148148
# result 033 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.146463ms workspace=0 mathMode=0 waves=0.148148
# result 034 : algo={ Id=1, tileIdx=11 (32x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.180890ms workspace=0 mathMode=0 waves=0.592593
# result 035 : algo={ Id=1, tileIdx=11 (32x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.180941ms workspace=0 mathMode=0 waves=0.592593
# result 036 : algo={ Id=1, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.204288ms workspace=0 mathMode=0 waves=0.592593
# result 037 : algo={ Id=1, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.204298ms workspace=0 mathMode=0 waves=0.592593
# result 038 : algo={ Id=1, tileIdx=13 (64x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.218225ms workspace=0 mathMode=0 waves=0.592593
# result 039 : algo={ Id=1, tileIdx=13 (64x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.218255ms workspace=0 mathMode=0 waves=0.592593
# result 040 : algo={ Id=0, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.366234ms workspace=0 mathMode=0 waves=0.148148
# result 041 : algo={ Id=0, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.366264ms workspace=0 mathMode=0 waves=0.148148
# result 042 : algo={ Id=0, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.454267ms workspace=0 mathMode=0 waves=0.148148
# result 043 : algo={ Id=0, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.454308ms workspace=0 mathMode=0 waves=0.148148
# result 044 : algo={ Id=0, tileIdx=14 (32x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.679025ms workspace=0 mathMode=0 waves=0.592593
# result 045 : algo={ Id=0, tileIdx=14 (32x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.679107ms workspace=0 mathMode=0 waves=0.592593
# result 046 : algo={ Id=0, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.760689ms workspace=0 mathMode=0 waves=0.296296
# result 047 : algo={ Id=0, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.760719ms workspace=0 mathMode=0 waves=0.296296
# result 048 : algo={ Id=0, tileIdx=15 (64x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.785603ms workspace=0 mathMode=0 waves=0.148148
# result 049 : algo={ Id=0, tileIdx=15 (64x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.785715ms workspace=0 mathMode=0 waves=0.148148
# algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.047688ms workspace=0 mathMode=0 waves=0.296296
# ***cublasLt Gemm Testing End***
#
# -----------------------------
# GEMM test 9: [M: 1, K: 8192, N: 4096] ffn gemm 2
# algo_99 costs 0.051ms
# algo_100 costs 0.051ms
# algo_101 costs 0.051ms
# algo_102 costs 0.052ms
# algo_103 costs 0.051ms
# algo_104 costs 0.051ms
# algo_105 costs 0.051ms
# algo_106 costs 0.052ms
# algo_107 costs 0.051ms
# algo_108 costs 0.051ms
# algo_109 costs 0.052ms
# algo_110 costs 0.051ms
# algo_111 costs 0.052ms
# algo_112 costs 0.052ms
# algo_113 costs 0.052ms
# algo_114 costs 0.051ms
# algo_115 costs 0.052ms
# fast_algo 108 costs 0.051 ms
# ***cublasLt Gemm Testing Beign***
# AlgoCount: 5000
# return 8 and run heuristic algo
# workspacesize==0, run 245 algos
# result 000 : algo={ Id=31, tileIdx=15 (64x64) splitK=1 reduc=0 swizzle=0 custom=0 stages=17} status 0 time 0.047688ms workspace=0 mathMode=0 waves=0.296296
# result 001 : algo={ Id=6, tileIdx=15 (64x64) splitK=1 reduc=0 swizzle=1 custom=0 stages=18} status 0 time 0.049398ms workspace=0 mathMode=0 waves=0.592593
# result 002 : algo={ Id=6, tileIdx=18 (128x64) splitK=3 reduc=4 swizzle=0 custom=0 stages=16} status 0 time 0.051220ms workspace=24576 mathMode=0 waves=0.888889
# result 003 : algo={ Id=21, tileIdx=21 (256x64) splitK=4 reduc=4 swizzle=0 custom=0 stages=10} status 0 time 0.052726ms workspace=32768 mathMode=0 waves=0.296296
# result 004 : algo={ Id=6, tileIdx=18 (128x64) splitK=2 reduc=1 swizzle=1 custom=0 stages=12} status 0 time 0.052992ms workspace=128 mathMode=0 waves=0.296296
# result 005 : algo={ Id=6, tileIdx=18 (128x64) splitK=4 reduc=4 swizzle=1 custom=0 stages=12} status 0 time 0.053320ms workspace=32768 mathMode=0 waves=0.592593
# result 006 : algo={ Id=6, tileIdx=18 (128x64) splitK=7 reduc=1 swizzle=0 custom=0 stages=16} status 0 time 0.056187ms workspace=128 mathMode=0 waves=2.074074
# result 007 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.065823ms workspace=0 mathMode=0 waves=0.148148
# result 008 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.065874ms workspace=0 mathMode=0 waves=0.148148
# result 009 : algo={ Id=13, tileIdx=0 (UNDEF) splitK=108 reduc=2 swizzle=0 custom=7 stages=0} status 0 time 0.083773ms workspace=1769488 mathMode=0 waves=3.200000
# result 010 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.102789ms workspace=0 mathMode=0 waves=0.296296
# result 011 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.102830ms workspace=0 mathMode=0 waves=0.296296
# result 012 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=11} status 0 time 0.103281ms workspace=0 mathMode=0 waves=0.148148
# result 013 : algo={ Id=6, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=11} status 0 time 0.103332ms workspace=0 mathMode=0 waves=0.148148
# result 014 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=15} status 0 time 0.197581ms workspace=0 mathMode=0 waves=0.296296
# result 015 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.197591ms workspace=0 mathMode=0 waves=0.148148
# result 016 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=15} status 0 time 0.197632ms workspace=0 mathMode=0 waves=0.296296
# result 017 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.197663ms workspace=0 mathMode=0 waves=0.148148
# result 018 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.207944ms workspace=0 mathMode=0 waves=0.296296
# result 019 : algo={ Id=6, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.208036ms workspace=0 mathMode=0 waves=0.296296
# result 020 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.210350ms workspace=0 mathMode=0 waves=0.148148
# result 021 : algo={ Id=5, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.210442ms workspace=0 mathMode=0 waves=0.148148
# result 022 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.215337ms workspace=0 mathMode=0 waves=0.074074
# result 023 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.215419ms workspace=0 mathMode=0 waves=0.074074
# result 024 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.230359ms workspace=0 mathMode=0 waves=0.074074
# result 025 : algo={ Id=6, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.230502ms workspace=0 mathMode=0 waves=0.074074
# result 026 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.243261ms workspace=0 mathMode=0 waves=0.296296
# result 027 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.243302ms workspace=0 mathMode=0 waves=0.296296
# result 028 : algo={ Id=5, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.245791ms workspace=0 mathMode=0 waves=0.148148
# result 029 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=1 custom=0 stages=7} status 0 time 0.245811ms workspace=0 mathMode=0 waves=0.296296
# result 030 : algo={ Id=5, tileIdx=24 (256x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.245873ms workspace=0 mathMode=0 waves=0.148148
# result 031 : algo={ Id=5, tileIdx=23 (128x256) splitK=0 reduc=0 swizzle=0 custom=0 stages=7} status 0 time 0.245934ms workspace=0 mathMode=0 waves=0.296296
# result 032 : algo={ Id=1, tileIdx=13 (64x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.264100ms workspace=0 mathMode=0 waves=0.296296
# result 033 : algo={ Id=1, tileIdx=13 (64x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.264161ms workspace=0 mathMode=0 waves=0.296296
# result 034 : algo={ Id=1, tileIdx=11 (32x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.268626ms workspace=0 mathMode=0 waves=0.296296
# result 035 : algo={ Id=1, tileIdx=11 (32x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.268667ms workspace=0 mathMode=0 waves=0.296296
# result 036 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.281774ms workspace=0 mathMode=0 waves=0.074074
# result 037 : algo={ Id=5, tileIdx=21 (256x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.281846ms workspace=0 mathMode=0 waves=0.074074
# result 038 : algo={ Id=1, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.400138ms workspace=0 mathMode=0 waves=0.296296
# result 039 : algo={ Id=1, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.400189ms workspace=0 mathMode=0 waves=0.296296
# result 040 : algo={ Id=0, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.748749ms workspace=0 mathMode=0 waves=0.074074
# result 041 : algo={ Id=0, tileIdx=16 (128x32) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.748790ms workspace=0 mathMode=0 waves=0.074074
# result 042 : algo={ Id=0, tileIdx=14 (32x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.862822ms workspace=0 mathMode=0 waves=0.296296
# result 043 : algo={ Id=0, tileIdx=14 (32x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.885023ms workspace=0 mathMode=0 waves=0.296296
# result 044 : algo={ Id=0, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.921549ms workspace=0 mathMode=0 waves=0.074074
# result 045 : algo={ Id=0, tileIdx=18 (128x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.922931ms workspace=0 mathMode=0 waves=0.074074
# result 046 : algo={ Id=0, tileIdx=15 (64x64) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 0.939940ms workspace=0 mathMode=0 waves=0.074074
# result 047 : algo={ Id=0, tileIdx=15 (64x64) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 0.939971ms workspace=0 mathMode=0 waves=0.074074
# result 048 : algo={ Id=0, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=0 custom=0 stages=0} status 0 time 1.513595ms workspace=0 mathMode=0 waves=0.148148
# result 049 : algo={ Id=0, tileIdx=20 (128x128) splitK=0 reduc=0 swizzle=1 custom=0 stages=0} status 0 time 1.513738ms workspace=0 mathMode=0 waves=0.148148
# algo={ Id=31, tileIdx=15 (64x64) splitK=1 reduc=0 swizzle=0 custom=0 stages=17} status 0 time 0.047688ms workspace=0 mathMode=0 waves=0.296296
# ***cublasLt Gemm Testing End***
#
# -----------------------------
# GEMM test 10: [M: 1, K: 4096, N: 25128] logits gemm
# algo_99 costs 0.135ms
# algo_100 costs 0.134ms
# algo_101 costs 0.134ms
# algo_102 costs 0.134ms
# algo_103 costs 0.134ms
# algo_104 costs 0.134ms
# algo_105 costs 0.134ms
# algo_106 costs 0.134ms
# algo_107 costs 0.135ms
# algo_108 costs 0.134ms
# algo_109 costs 0.135ms
# algo_110 costs 0.135ms
# algo_111 costs 0.135ms
# algo_112 costs 0.135ms
# algo_113 costs 0.135ms
# algo_114 costs 0.135ms
# algo_115 costs 0.135ms
# fast_algo 101 costs 0.134 ms
# ***cublas Gemm Testing End***
#
# ***GPT Gemm Testing End***

# %% [markdown]
# This script will test many possible kernels and save the optimal configuration in `gemm_config.in` file. This file needs to be placed in the model directory.

# %% [markdown]
# # 4.5 Launching Triton Inference Server

# %% [markdown]
# Let us now bring all the parts together and start Triton hosting our GPT-J inference pipeline: </br>
# 1. We have built and started Triton docker container with the FasterTransformer backend that supports distributed inference of GPT-J</br>
# 2. We have downloaded model weights and converted them into FasterTransforer format. </br>
# 3. We have prepared the Triton configuration file 'config.pbtxt'.</br>
#
# We are ready to start Triton Inference Server!

# %% [markdown]
# The command that we are going to use is as follows: </br>
# <code>"CUDA_VISIBLE_DEVICES=2,3 mpirun -n 1 --allow-run-as-root /opt/tritonserver/bin/tritonserver  --model-repository=./triton-model-store/gptj/ &</code> </br>
#
# Let us look at the command segment at a time:
# - CUDA_VISIBLE_DEVICES environment variable chooses which GPU will be used for current task/process/script. We have 4 GPUs on our system, so we will use GPUs 3 and 4 (with numbers 2,3) to be sure that we use unused before GPUs to avoid OOM error.
# - mpirun - is a command that will allow us to execute Triton in a mode allowing for multi node execution. In this case the parameter -n indicating the number of nodes is set to 1 meaning that only one server will be used. One could specify higher number deploying across multiple servers in our datacenter.
# - <code>--model-repository=some_path</code>, which points to the directory where we have placed configuration files for all models that Triton will be serving (Triton can happily serve multiple models/pipelines). Triton will automatically scan through this folder, find model configurations, load them onto the GPUs and open the HTTP (8000) and GRPC (8001) ports to handle requests.

# %% [markdown]
# <b>We will start Triton as a subprocess using Python's `os.system` API. All output logs will be printed into our jupyter output. We do this to not to block Jupyter, which would stop at this command until triton is terminated.</b></br>
# If Triton starts successfully, we will see these lines in the output. </br>
# It will display information about the ensemble of GPT-J stages that were found by the Triton in our model directory: </br>
#
# <code>
# +-------------------+---------+--------+
# | Model             | Version | Status |
# +-------------------+---------+--------+
# | ensemble          | 1       | READY  |
# | fastertransformer | 1       | READY  |
# | postprocessing    | 1       | READY  |
# | preprocessing     | 1       | READY  |
# +-------------------+---------+--------+</code>
# </br></br>
# It will also display information about successful service initialization: </br>
#
# <code>
# I0503 17:26:25.226719 1668 grpc_server.cc:4421] Started GRPCInferenceService at 0.0.0.0:8001
# I0503 17:26:25.227017 1668 http_server.cc:3113] Started HTTPService at 0.0.0.0:8000
# I0503 17:26:25.283046 1668 http_server.cc:178] Started Metrics Service at 0.0.0.0:8002</code>

# %%
import os
os.system("CUDA_VISIBLE_DEVICES=2,3 mpirun -n 1 --allow-run-as-root /opt/tritonserver/bin/tritonserver  --model-repository=./triton-model-store/gptj/ &")
# Out:
# 0
# I0323 22:15:13.995418 10849 metrics.cc:298] Collecting metrics for GPU 0: Graphics Device
# I0323 22:15:13.995589 10849 metrics.cc:298] Collecting metrics for GPU 1: Graphics Device
# I0323 22:15:14.215486 10849 libtorch.cc:1227] TRITONBACKEND_Initialize: pytorch
# I0323 22:15:14.215532 10849 libtorch.cc:1237] Triton TRITONBACKEND API version: 1.7
# I0323 22:15:14.215535 10849 libtorch.cc:1243] 'pytorch' TRITONBACKEND API version: 1.7
# 2023-03-23 22:15:14.328974: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2023-03-23 22:15:14.352362: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# I0323 22:15:14.352437 10849 tensorflow.cc:2176] TRITONBACKEND_Initialize: tensorflow
# I0323 22:15:14.352458 10849 tensorflow.cc:2186] Triton TRITONBACKEND API version: 1.7
# I0323 22:15:14.352463 10849 tensorflow.cc:2192] 'tensorflow' TRITONBACKEND API version: 1.7
# I0323 22:15:14.352466 10849 tensorflow.cc:2216] backend configuration:
# {}
# I0323 22:15:14.357279 10849 onnxruntime.cc:2232] TRITONBACKEND_Initialize: onnxruntime
# I0323 22:15:14.357296 10849 onnxruntime.cc:2242] Triton TRITONBACKEND API version: 1.7
# I0323 22:15:14.357300 10849 onnxruntime.cc:2248] 'onnxruntime' TRITONBACKEND API version: 1.7
# I0323 22:15:14.357303 10849 onnxruntime.cc:2278] backend configuration:
# {}
# I0323 22:15:14.375628 10849 openvino.cc:1234] TRITONBACKEND_Initialize: openvino
# I0323 22:15:14.375646 10849 openvino.cc:1244] Triton TRITONBACKEND API version: 1.7
# I0323 22:15:14.375650 10849 openvino.cc:1250] 'openvino' TRITONBACKEND API version: 1.7
# I0323 22:15:14.493119 10849 pinned_memory_manager.cc:240] Pinned memory pool is created at '0x7fd908000000' with size 268435456
# I0323 22:15:14.494775 10849 cuda_memory_manager.cc:105] CUDA memory pool is created on device 0 with size 67108864
# I0323 22:15:14.494786 10849 cuda_memory_manager.cc:105] CUDA memory pool is created on device 1 with size 67108864
# I0323 22:15:14.572997 10849 model_repository_manager.cc:994] loading: postprocessing:1
# W0323 22:15:14.673612 10849 model_repository_manager.cc:203] ignore version directory '.ipynb_checkpoints' which fails to convert to integral number
# I0323 22:15:14.673675 10849 model_repository_manager.cc:994] loading: fastertransformer:1
# I0323 22:15:14.677425 10849 python.cc:1897] TRITONBACKEND_ModelInstanceInitialize: postprocessing_0 (CPU device 0)
# I0323 22:15:14.774028 10849 model_repository_manager.cc:994] loading: preprocessing:1
# I0323 22:15:15.318895 10849 model_repository_manager.cc:1149] successfully loaded 'postprocessing' version 1
# I0323 22:15:15.407483 10849 libfastertransformer.cc:1226] TRITONBACKEND_Initialize: fastertransformer
# I0323 22:15:15.407512 10849 libfastertransformer.cc:1236] Triton TRITONBACKEND API version: 1.7
# I0323 22:15:15.407516 10849 libfastertransformer.cc:1242] 'fastertransformer' TRITONBACKEND API version: 1.7
# I0323 22:15:15.407562 10849 libfastertransformer.cc:1274] TRITONBACKEND_ModelInitialize: fastertransformer (version 1)
# W0323 22:15:15.408074 10849 libfastertransformer.cc:149] model configuration:
# {
#     "name": "fastertransformer",
#     "platform": "",
#     "backend": "fastertransformer",
#     "version_policy": {
#         "latest": {
#             "num_versions": 1
#         }
#     },
#     "max_batch_size": 1024,
#     "input": [
#         {
#             "name": "input_ids",
#             "data_type": "TYPE_UINT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         },
#         {
#             "name": "start_id",
#             "data_type": "TYPE_UINT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "reshape": {
#                 "shape": []
#             },
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": true
#         },
#         {
#             "name": "end_id",
#             "data_type": "TYPE_UINT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "reshape": {
#                 "shape": []
#             },
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": true
#         },
#         {
#             "name": "input_lengths",
#             "data_type": "TYPE_UINT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "reshape": {
#                 "shape": []
#             },
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         },
#         {
#             "name": "request_output_len",
#             "data_type": "TYPE_UINT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         },
#         {
#             "name": "runtime_top_k",
#             "data_type": "TYPE_UINT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "reshape": {
#                 "shape": []
#             },
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": true
#         },
#         {
#             "name": "runtime_top_p",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "reshape": {
#                 "shape": []
#             },
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": true
#         },
#         {
#             "name": "beam_search_diversity_rate",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "reshape": {
#                 "shape": []
#             },
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": true
#         },
#         {
#             "name": "temperature",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "reshape": {
#                 "shape": []
#             },
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": true
#         },
#         {
#             "name": "len_penalty",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "reshape": {
#                 "shape": []
#             },
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": true
#         },
#         {
#             "name": "repetition_penalty",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "reshape": {
#                 "shape": []
#             },
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": true
#         },
#         {
#             "name": "random_seed",
#             "data_type": "TYPE_INT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "reshape": {
#                 "shape": []
#             },
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": true
#         },
#         {
#             "name": "is_return_log_probs",
#             "data_type": "TYPE_BOOL",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "reshape": {
#                 "shape": []
#             },
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": true
#         },
#         {
#             "name": "beam_width",
#             "data_type": "TYPE_UINT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "reshape": {
#                 "shape": []
#             },
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": true
#         },
#         {
#             "name": "bad_words_list",
#             "data_type": "TYPE_INT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 2,
#                 -1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": true
#         },
#         {
#             "name": "stop_words_list",
#             "data_type": "TYPE_INT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 2,
#                 -1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": true
#         }
#     ],
#     "output": [
#         {
#             "name": "output_ids",
#             "data_type": "TYPE_UINT32",
#             "dims": [
#                 -1,
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "sequence_length",
#             "data_type": "TYPE_UINT32",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "cum_log_probs",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "output_log_probs",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 -1,
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         }
#     ],
#     "batch_input": [],
#     "batch_output": [],
#     "optimization": {
#         "priority": "PRIORITY_DEFAULT",
#         "input_pinned_memory": {
#             "enable": true
#         },
#         "output_pinned_memory": {
#             "enable": true
#         },
#         "gather_kernel_buffer_threshold": 0,
#         "eager_batching": false
#     },
#     "instance_group": [
#         {
#             "name": "fastertransformer_0",
#             "kind": "KIND_CPU",
#             "count": 1,
#             "gpus": [],
#             "secondary_devices": [],
#             "profile": [],
#             "passive": false,
#             "host_policy": ""
#         }
#     ],
#     "default_model_filename": "gpt-j-6b",
#     "cc_model_filenames": {},
#     "metric_tags": {},
#     "parameters": {
#         "end_id": {
#             "string_value": "50256"
#         },
#         "inter_size": {
#             "string_value": "16384"
#         },
#         "head_num": {
#             "string_value": "16"
#         },
#         "model_type": {
#             "string_value": "GPT-J"
#         },
#         "model_checkpoint_path": {
#             "string_value": "./models/j6b_ckpt/2-gpu/"
#         },
#         "rotary_embedding": {
#             "string_value": "64"
#         },
#         "pipeline_para_size": {
#             "string_value": "1"
#         },
#         "start_id": {
#             "string_value": "50256"
#         },
#         "model_name": {
#             "string_value": "gptj-6-b"
#         },
#         "is_half": {
#             "string_value": "1"
#         },
#         "enable_custom_all_reduce": {
#             "string_value": "0"
#         },
#         "vocab_size": {
#             "string_value": "50400"
#         },
#         "tensor_para_size": {
#             "string_value": "2"
#         },
#         "decoder_layers": {
#             "string_value": "28"
#         },
#         "size_per_head": {
#             "string_value": "256"
#         },
#         "max_seq_len": {
#             "string_value": "528"
#         }
#     },
#     "model_warmup": []
# }
# I0323 22:15:15.409879 10849 libfastertransformer.cc:1320] TRITONBACKEND_ModelInstanceInitialize: fastertransformer_0 (device 0)
# W0323 22:15:15.409902 10849 libfastertransformer.cc:453] Faster transformer model instance is created at GPU '0'
# W0323 22:15:15.409905 10849 libfastertransformer.cc:459] Model name gpt-j-6b
# W0323 22:15:15.409911 10849 libfastertransformer.cc:578] Get input name: input_ids, type: TYPE_UINT32, shape: [-1]
# W0323 22:15:15.409914 10849 libfastertransformer.cc:578] Get input name: start_id, type: TYPE_UINT32, shape: [1]
# W0323 22:15:15.409917 10849 libfastertransformer.cc:578] Get input name: end_id, type: TYPE_UINT32, shape: [1]
# W0323 22:15:15.409920 10849 libfastertransformer.cc:578] Get input name: input_lengths, type: TYPE_UINT32, shape: [1]
# W0323 22:15:15.409923 10849 libfastertransformer.cc:578] Get input name: request_output_len, type: TYPE_UINT32, shape: [-1]
# W0323 22:15:15.409925 10849 libfastertransformer.cc:578] Get input name: runtime_top_k, type: TYPE_UINT32, shape: [1]
# W0323 22:15:15.409928 10849 libfastertransformer.cc:578] Get input name: runtime_top_p, type: TYPE_FP32, shape: [1]
# W0323 22:15:15.409930 10849 libfastertransformer.cc:578] Get input name: beam_search_diversity_rate, type: TYPE_FP32, shape: [1]
# W0323 22:15:15.409934 10849 libfastertransformer.cc:578] Get input name: temperature, type: TYPE_FP32, shape: [1]
# W0323 22:15:15.409937 10849 libfastertransformer.cc:578] Get input name: len_penalty, type: TYPE_FP32, shape: [1]
# W0323 22:15:15.409940 10849 libfastertransformer.cc:578] Get input name: repetition_penalty, type: TYPE_FP32, shape: [1]
# W0323 22:15:15.409943 10849 libfastertransformer.cc:578] Get input name: random_seed, type: TYPE_INT32, shape: [1]
# W0323 22:15:15.409946 10849 libfastertransformer.cc:578] Get input name: is_return_log_probs, type: TYPE_BOOL, shape: [1]
# W0323 22:15:15.409948 10849 libfastertransformer.cc:578] Get input name: beam_width, type: TYPE_UINT32, shape: [1]
# W0323 22:15:15.409951 10849 libfastertransformer.cc:578] Get input name: bad_words_list, type: TYPE_INT32, shape: [2, -1]
# W0323 22:15:15.409954 10849 libfastertransformer.cc:578] Get input name: stop_words_list, type: TYPE_INT32, shape: [2, -1]
# W0323 22:15:15.409959 10849 libfastertransformer.cc:620] Get output name: output_ids, type: TYPE_UINT32, shape: [-1, -1]
# W0323 22:15:15.409962 10849 libfastertransformer.cc:620] Get output name: sequence_length, type: TYPE_UINT32, shape: [-1]
# W0323 22:15:15.409967 10849 libfastertransformer.cc:620] Get output name: cum_log_probs, type: TYPE_FP32, shape: [-1]
# W0323 22:15:15.409971 10849 libfastertransformer.cc:620] Get output name: output_log_probs, type: TYPE_FP32, shape: [-1, -1]
# [FT][WARNING] Custom All Reduce only supports 8 Ranks currently. Using NCCL as Comm.
# I0323 22:15:15.885852 10849 libfastertransformer.cc:307] Before Loading Model:
# after allocation, free 77.75 GB total 79.35 GB
# after allocation, free 77.75 GB total 79.35 GB

# %% [markdown]
# # 4.6 Writing client application consuming our GPT-J model

# %% [markdown]
# Finally, we are ready to consume our GPT-J model. We will write a simple python application sending text input to the server using Python's tritonclient library.
#
# We will send requests to the "ensemble" model not to the GPT-J part as we want pre and post processing to be executed on the server side. Triton is flexible, and we can separately request just the GPT-J model or any part of the pipeline.

# %%
import numpy as np
import tritonclient.http as httpclient

from tritonclient.utils import np_to_triton_dtype

URL = "localhost:8000"
MODEl_GPTJ_FASTERTRANSFORMER = "ensemble" 

OUTPUT_LEN = 128
BATCH_SIZE = 1
BEAM_WIDTH = 1
TOP_K = 1
TOP_P = 0.0

start_id = 220
end_id = 50256

# %% [markdown]
# To create an instance of the `client`:

# %%
client = httpclient.InferenceServerClient("localhost:8000",
                                           concurrency=1,
                                           verbose=False)
# Out:
# I0323 22:15:26.624169 10849 libfastertransformer.cc:321] After Loading Model:
# I0323 22:15:26.652322 10849 libfastertransformer.cc:537] Model instance is created on GPU Graphics Device
# I0323 22:15:26.652487 10849 python.cc:1897] TRITONBACKEND_ModelInstanceInitialize: preprocessing_0 (CPU device 0)
# I0323 22:15:26.653136 10849 model_repository_manager.cc:1149] successfully loaded 'fastertransformer' version 1
# after allocation, free 71.36 GB total 79.35 GB
# after allocation, free 71.36 GB total 79.35 GB
# I0323 22:15:27.412432 10849 model_repository_manager.cc:1149] successfully loaded 'preprocessing' version 1
# I0323 22:15:27.412972 10849 model_repository_manager.cc:994] loading: ensemble:1
# I0323 22:15:27.513528 10849 model_repository_manager.cc:1149] successfully loaded 'ensemble' version 1
# I0323 22:15:27.513819 10849 server.cc:519]
# +------------------+------+
# | Repository Agent | Path |
# +------------------+------+
# +------------------+------+
#
# I0323 22:15:27.513897 10849 server.cc:546]
# +-------------------+-----------------------------------------------------------------------------+--------+
# | Backend           | Path                                                                        | Config |
# +-------------------+-----------------------------------------------------------------------------+--------+
# | pytorch           | /opt/tritonserver/backends/pytorch/libtriton_pytorch.so                     | {}     |
# | onnxruntime       | /opt/tritonserver/backends/onnxruntime/libtriton_onnxruntime.so             | {}     |
# | openvino          | /opt/tritonserver/backends/openvino_2021_2/libtriton_openvino_2021_2.so     | {}     |
# | tensorflow        | /opt/tritonserver/backends/tensorflow1/libtriton_tensorflow1.so             | {}     |
# | python            | /opt/tritonserver/backends/python/libtriton_python.so                       | {}     |
# | fastertransformer | /opt/tritonserver/backends/fastertransformer/libtriton_fastertransformer.so | {}     |
# +-------------------+-----------------------------------------------------------------------------+--------+
#
# I0323 22:15:27.513953 10849 server.cc:589]
# +-------------------+---------+--------+
# | Model             | Version | Status |
# +-------------------+---------+--------+
# | ensemble          | 1       | READY  |
# | fastertransformer | 1       | READY  |
# | postprocessing    | 1       | READY  |
# | preprocessing     | 1       | READY  |
# +-------------------+---------+--------+
#
# I0323 22:15:27.514063 10849 tritonserver.cc:1865]
# +----------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Option                           | Value                                                                                                                                                                                  |
# +----------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | server_id                        | triton                                                                                                                                                                                 |
# | server_version                   | 2.18.0                                                                                                                                                                                 |
# | server_extensions                | classification sequence model_repository model_repository(unload_dependents) schedule_policy model_configuration system_shared_memory cuda_shared_memory binary_tensor_data statistics |
# | model_repository_path[0]         | ./triton-model-store/gptj/                                                                                                                                                             |
# | model_control_mode               | MODE_NONE                                                                                                                                                                              |
# | strict_model_config              | 1                                                                                                                                                                                      |
# | rate_limit                       | OFF                                                                                                                                                                                    |
# | pinned_memory_pool_byte_size     | 268435456                                                                                                                                                                              |
# | cuda_memory_pool_byte_size{0}    | 67108864                                                                                                                                                                               |
# | cuda_memory_pool_byte_size{1}    | 67108864                                                                                                                                                                               |
# | response_cache_byte_size         | 0                                                                                                                                                                                      |
# | min_supported_compute_capability | 6.0                                                                                                                                                                                    |
# | strict_readiness                 | 1                                                                                                                                                                                      |
# | exit_timeout                     | 30                                                                                                                                                                                     |
# +----------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# I0323 22:15:27.516016 10849 grpc_server.cc:4195] Started GRPCInferenceService at 0.0.0.0:8001
# I0323 22:15:27.516214 10849 http_server.cc:2857] Started HTTPService at 0.0.0.0:8000
# I0323 22:15:27.558725 10849 http_server.cc:167] Started Metrics Service at 0.0.0.0:8002

# %% [markdown]
# We will implement a function `prepare inputs` that prepares input text and other inference hyperparameters such as `Top-k`, `Top-P`, `Temperature`, etc. There are 15 different hyperparameters that need to be defined for the GPT-J `ensemble` execution.

# %%
# Inference hyperparameters
def prepare_tensor(name, input):
    tensor = httpclient.InferInput(
        name, input.shape, np_to_triton_dtype(input.dtype))
    tensor.set_data_from_numpy(input)
    return tensor

# explanation
def prepare_inputs(input0):
    bad_words_list = np.array([[""]], dtype=object)
    stop_words_list = np.array([[""]], dtype=object)
    input0_data = np.array(input0).astype(object)
    output0_len = np.ones_like(input0).astype(np.uint32) * OUTPUT_LEN
    runtime_top_k = (TOP_K * np.ones([input0_data.shape[0], 1])).astype(np.uint32)
    runtime_top_p = TOP_P * np.ones([input0_data.shape[0], 1]).astype(np.float32)
    beam_search_diversity_rate = 0.0 * np.ones([input0_data.shape[0], 1]).astype(np.float32)
    temperature = 1.0 * np.ones([input0_data.shape[0], 1]).astype(np.float32)
    len_penalty = 1.0 * np.ones([input0_data.shape[0], 1]).astype(np.float32)
    repetition_penalty = 1.0 * np.ones([input0_data.shape[0], 1]).astype(np.float32)
    random_seed = 0 * np.ones([input0_data.shape[0], 1]).astype(np.int32)
    is_return_log_probs = True * np.ones([input0_data.shape[0], 1]).astype(bool)
    beam_width = (BEAM_WIDTH * np.ones([input0_data.shape[0], 1])).astype(np.uint32)
    start_ids = start_id * np.ones([input0_data.shape[0], 1]).astype(np.uint32)
    end_ids = end_id * np.ones([input0_data.shape[0], 1]).astype(np.uint32)

    inputs = [
        prepare_tensor("INPUT_0", input0_data),
        prepare_tensor("INPUT_1", output0_len),
        prepare_tensor("INPUT_2", bad_words_list),
        prepare_tensor("INPUT_3", stop_words_list),
        prepare_tensor("runtime_top_k", runtime_top_k),
        prepare_tensor("runtime_top_p", runtime_top_p),
        prepare_tensor("beam_search_diversity_rate", beam_search_diversity_rate),
        prepare_tensor("temperature", temperature),
        prepare_tensor("len_penalty", len_penalty),
        prepare_tensor("repetition_penalty", repetition_penalty),
        prepare_tensor("random_seed", random_seed),
        prepare_tensor("is_return_log_probs", is_return_log_probs),
        prepare_tensor("beam_width", beam_width),
        prepare_tensor("start_id", start_ids),
        prepare_tensor("end_id", end_ids),
    ]
    return inputs

# %% [markdown]
# We can input any prompt for the GPT-J model and execute the cell:

# %%
print("Write an input prompt for the model and execute the cell:")
input_user = input()
input0 = [[input_user],]
inputs = prepare_inputs(input0)
# Out:
# Write an input prompt for the model and execute the cell:
#  What is your name?

# %% [markdown]
# Send the request to the server.</br>
# <b>We will see output logs of the Triton server together with our generated output.</b>

# %%
result = client.infer(MODEl_GPTJ_FASTERTRANSFORMER, inputs)
output0 = result.as_numpy("OUTPUT_0")
print(output0)
# Out:
# W0323 22:15:47.650855 10849 libfastertransformer.cc:1397] model fastertransformer, instance fastertransformer_0, executing 1 requests
# W0323 22:15:47.650909 10849 libfastertransformer.cc:638] TRITONBACKEND_ModelExecute: Running fastertransformer_0 with 1 requests
# W0323 22:15:47.650919 10849 libfastertransformer.cc:693] get total batch_size = 1
# W0323 22:15:47.650931 10849 libfastertransformer.cc:1051] get input count = 16
# W0323 22:15:47.650946 10849 libfastertransformer.cc:1117] collect name: len_penalty size: 4 bytes
# W0323 22:15:47.650953 10849 libfastertransformer.cc:1117] collect name: temperature size: 4 bytes
# W0323 22:15:47.650960 10849 libfastertransformer.cc:1117] collect name: runtime_top_k size: 4 bytes
# W0323 22:15:47.650966 10849 libfastertransformer.cc:1117] collect name: end_id size: 4 bytes
# W0323 22:15:47.650979 10849 libfastertransformer.cc:1117] collect name: runtime_top_p size: 4 bytes
# W0323 22:15:47.650984 10849 libfastertransformer.cc:1117] collect name: request_output_len size: 4 bytes
# W0323 22:15:47.650988 10849 libfastertransformer.cc:1117] collect name: beam_search_diversity_rate size: 4 bytes
# W0323 22:15:47.650992 10849 libfastertransformer.cc:1117] collect name: beam_width size: 4 bytes
# W0323 22:15:47.650996 10849 libfastertransformer.cc:1117] collect name: repetition_penalty size: 4 bytes
# W0323 22:15:47.651000 10849 libfastertransformer.cc:1117] collect name: start_id size: 4 bytes
# W0323 22:15:47.651003 10849 libfastertransformer.cc:1117] collect name: input_ids size: 20 bytes
# W0323 22:15:47.651007 10849 libfastertransformer.cc:1117] collect name: stop_words_list size: 8 bytes
# W0323 22:15:47.651011 10849 libfastertransformer.cc:1117] collect name: is_return_log_probs size: 1 bytes
# W0323 22:15:47.651015 10849 libfastertransformer.cc:1117] collect name: random_seed size: 4 bytes
# W0323 22:15:47.651019 10849 libfastertransformer.cc:1117] collect name: bad_words_list size: 8 bytes
# W0323 22:15:47.651023 10849 libfastertransformer.cc:1117] collect name: input_lengths size: 4 bytes
# W0323 22:15:47.651026 10849 libfastertransformer.cc:1130] the data is in CPU
# W0323 22:15:47.651029 10849 libfastertransformer.cc:1137] the data is in CPU
# W0323 22:15:47.651038 10849 libfastertransformer.cc:999] before ThreadForward 0
# W0323 22:15:47.651425 10849 libfastertransformer.cc:1006] after ThreadForward 0
# W0323 22:15:47.651435 10849 libfastertransformer.cc:999] before ThreadForward 1
# W0323 22:15:47.651475 10849 libfastertransformer.cc:1006] after ThreadForward 1
# I0323 22:15:47.651541 10849 libfastertransformer.cc:834] Start to forward
# I0323 22:15:47.651556 10849 libfastertransformer.cc:834] Start to forward
# [b"What is your name?\n\nMy name is John.\n\nWhat is your age?\n\nI am twenty-five.\n\nWhat is your occupation?\n\nI am a teacher.\n\nWhat is your marital status?\n\nI am married.\n\nWhat is your father's name?\n\nMy father's name is John.\n\nWhat is your mother's name?\n\nMy mother's name is Mary.\n\nWhat is your father's occupation?\n\nMy father is a teacher.\n\nWhat is your mother's occupation?\n\nMy mother is a teacher.\n\nWhat is your father's place"]
# I0323 22:15:48.464557 10849 libfastertransformer.cc:836] Stop to forward
# I0323 22:15:48.464619 10849 libfastertransformer.cc:836] Stop to forward
# W0323 22:15:48.464763 10849 libfastertransformer.cc:1161] Get output_tensors 0: sequence_length
# W0323 22:15:48.464799 10849 libfastertransformer.cc:1171]     output_type: INT32
# W0323 22:15:48.464805 10849 libfastertransformer.cc:1191]     output shape: [1, 1]
# W0323 22:15:48.464890 10849 libfastertransformer.cc:1161] Get output_tensors 1: output_ids
# W0323 22:15:48.464903 10849 libfastertransformer.cc:1171]     output_type: UINT32
# W0323 22:15:48.464908 10849 libfastertransformer.cc:1191]     output shape: [1, 1, 133]
# W0323 22:15:48.464921 10849 libfastertransformer.cc:1161] Get output_tensors 2: output_log_probs
# W0323 22:15:48.464931 10849 libfastertransformer.cc:1171]     output_type: FP32
# W0323 22:15:48.464935 10849 libfastertransformer.cc:1191]     output shape: [1, 1, 128]
# W0323 22:15:48.464946 10849 libfastertransformer.cc:1161] Get output_tensors 3: cum_log_probs
# W0323 22:15:48.464955 10849 libfastertransformer.cc:1171]     output_type: FP32
# W0323 22:15:48.464959 10849 libfastertransformer.cc:1191]     output shape: [1, 1]
# W0323 22:15:48.464979 10849 libfastertransformer.cc:1206] PERFORMED GPU copy: YES
# W0323 22:15:48.464989 10849 libfastertransformer.cc:780] get response size = 1
# W0323 22:15:48.465049 10849 libfastertransformer.cc:795] response is sent

# %% [markdown]
# ## Results

# %% [markdown]
# Now you know how to run large models in production. Triton Inference Server allows you to access your model from any device in the world.

# %% [markdown]
# To conclude let us review the end-to-end pipeline summary again:

# %% [markdown]
# <div style="text-align:center">
# <img src="./images/GPT-J.png" style="width: 60%;position:relative;"><br/>
# </div>

# %% [markdown]
# <h2 style="color:green;">Congratulations!</h2>
#
# Congratulations on finishing the course! If you're ready to put your skills to the test, please move on to the assessment.
